# %% [markdown]
# ## PROGRAMMING_FOR_DATA_ANALYSIS
#
# ## Project2
#
# Author: Jarlath Scarry
#
# Date: Dec 2022 to Jan 2023

# %% [markdown]
# <h1><center>Introduction</center></h1>
#
# There were an estimated 18.1 million new cases of cancer worldwide in 2020. Breast cancer and lung cancer were the most common types accounting for 12.5% and 12.2% of cases respectively. Each year in Ireland, more than 3,500 women and approximately 35 men are diagnosed with breast cancer.  It is more common in women over 50. Breast cancer is treated with surgery, radiotherapy, chemotherapy, hormone therapy and targeted therapies, depending on the type. Finding cancer early saves lives and can mean that the cancer is easier to treat. Less than 1 in 100 women screened are diagnosed with cancer, and these women have an good chance of successful treatment. Breast screening is a very effective way of spotting breast cancer early. (cancer.ie screening for breastcancer Nov 2022)  [7] [3]
#
# Cancer is a disease that is caused by groth of cells in an uncontrolled maner in the body. These rapidly dividing cells form masses in the breast called tumors. Tumors are divided into two groups as benign and malignant. Malignant tumors grow and damage adjacent healthy tissue. Harmful cells inside the tumor can also spread to different organs of the body. This is known as metastasis.
#
# There is a good chance of recovery from breast cancer if it is identified an early stage and treated, Therefore many studies have been carried out on its early diagnosis. Quite alot of research has gone into imaging and image analysis. A number of different medical imaging techniques are commonly used for diagnosis, more so than any other testing method. Medical imaging modalities used for breast cancer detection include histopathology (hp) images, breast X-ray images (mammography), sonograms (ultrasound imaging), and magnetic resonance imaging (MRI) are broadly used for diagnosis, with the mammogram being the most common method used. If something suspicious is found following this imaging a biopsy is often carried out. A common method of breast cancer biopsy is a Fine Needle Aspiration (FNA). During a FNA, a small amount of breast tissue or fluid is removed from a suspicious area with a thin, hollow needle and checked for cancer cells.

# %% [markdown]
# *****
# ### Proposed steps
# The Proposed steps in the project are outlined below
#
#     1. Data Aquisition
#                    Load the WDBC dataset from a reliable source
#
#     2. Pre-processing of the data
#                    Data Cleansing
#                    Feature selection
#
#     3. Build Program
#                     Train
#                     Test
#
#     4. Results Calculation and Evaluation
#                     Run the algorithm and evaluate the results

# %% [markdown]
# ### The Wisconsin Diagnostic Bresat Cancer Dataset
#
# The Wisconsin Diagnostic Bresat Cancer Dataset (WDBC) is seen by many as a benchmark dataset for training classification algorithms and is often referred to in these studies. The WDBC dataset is often used because of the relativley large number of inatances in the dataset is also relativley noise-free with fewoutliers or missing values.
#
# The WDBC is a classification dataset, which records the measurements for breast cancer cases. This dataset came from the work of Dr. William H. Wolberg and his team at the departments of Surgery and Human Oncology at the University of Wisconsin-Madison. (Machine Learning for Cancer Diagnosis and Prognosis, Dec 2022) [4] He and his team had a desire to diagnose breast masses accurately based solely on a FNA. They used fluid samples, taken from patients with solid breast masses and computer program called Xcyt to analyse the images. They identified nine visually assessed characteristics of an FNA sample which they considered relevant to diagnosis.  In collaboration with Prof. Mangasarian and two of his graduate students, Rudy Setiono and Kristin Bennett, a classifier was constructed using the multisurface method (MSM) of pattern separation on these nine features that successfully diagnosed 97% of new cases. The resulting data set is well-known as the Wisconsin Breast Cancer Data. It was donated in 1995 be W. Nick Street of the Computer Sciences Dept at the University of Wisconsin. [2]
#
# In this project I aim carryout a literature review of the dataset, train a set of classifiers on the dataset and compare and contrast these with the existing litrature. Data analysis machine learning algorithms used in this project are in the Python programming language and from the Scikit-learn library (sklearn). Sklearn is a free software machine learning library of algoritnms for the Python programming language. It contains many classification regression and
# clustering algorithms including all those listed later in the project. [8]

# %% [markdown]
# ### Data set Overview and Background
#
# The (WDBC) is a classification dataset in which measurments for breast cancer cases are recorded. It contains information from samples taken from Breast Cancer patients with Malignant and Benign tumors. The Breast cancer databases was obtained from the University of Wisconsin Hospitals, Madison from Dr. William H. Wolberg [A]
#
# I downloaded the dataset from kaggle.com and saved it in the data folder in the directory as data.csv (kaggle.com, Breast Cancer Wisconsin (Diagnostic) Data Set, Nov 2022) [1]
#
#
# #### Dataset detailed information:
#
# Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass. They describe characteristics of the cell nuclei present in the image. A few of the images can be found at [Web Link]
#
#
# Separating plane described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree. Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.
#
# The actual linear program used to obtain the separating plane in the 3-dimensional space is that described in: [K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].
# [2](uci breast cancer wisconsin, Dec 2022)
#
# #### Database Attribute Information:
#
# 1) ID number
# 2) Diagnosis (M = malignant, B = benign)
# 3-32)
#
# Ten real-valued features are computed for each cell nucleus:
#
# a) radius (mean of distances from center to points on the perimeter)
# b) texture (standard deviation of gray-scale values)
# c) perimeter
# d) area
# e) smoothness (local variation in radius lengths)
# f) compactness (perimeter^2 / area - 1.0)
# g) concavity (severity of concave portions of the contour)
# h) concave points (number of concave portions of the contour)
# i) symmetry
# j) fractal dimension ("coastline approximation" - 1)
#
# [2] (uci breast cancer wisconsin, Dec 2022) https://archive.ics.uci.edu/ml/datasets/breast+cancer+wisconsin+(diagnostic)

# %% [markdown]
# <h1><center>Exploratory Data Analysis</center></h1>
# After downloading the dataset I carried out an initial review Using a few pandas df commands we get a picture of the size and type of dataset we have. I checked the shape, null data points and the diagnosis counts for M and B.
#
# It is a multivariate dataset as it contains 2 categories; Benign (B) or Malignant (M). It contains 569 rows × 33 columns with no null points.  It contains 32 attributes for 569 instances (357 benign and 212 malignant). These are displayed on chart 1 below.
#
# Also using the groupby() feature we can group the data by classification M or B.  Feature means are grouped by diagnosis and displayed on a table.

# %%
#some initial imports
import numpy as np # Numerical arrays.
import matplotlib.pyplot as plt # Plotting.
import scipy.stats as ss # Statistics.
import pandas as pd
from datetime import date
import seaborn as sns

# import models from Scikit-learn [B]
from sklearn.linear_model import LogisticRegression 
from sklearn.linear_model import LinearRegression
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# import model evaluation tools 
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import plot_roc_curve

# %%
df = pd.read_csv("data/data.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.describe().T  #display description with df transposed
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
df.isnull().sum() #check for null data points
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
df["diagnosis"].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df.diagnosis.value_counts().plot(kind="bar", color=["green", "red"]);
plt.title("Chart 1.  Diagnosis counts")
# Out:
# Text(0.5, 1.0, 'Chart 1.  Diagnosis counts')

# %%
#Feature means grouped by diagnosis
df.groupby('diagnosis').mean()
# Out:
#                      id  radius_mean  texture_mean  perimeter_mean  \
# diagnosis
# B          2.654382e+07    12.146524     17.914762       78.075406
# M          3.681805e+07    17.462830     21.604906      115.365377
#
#             area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# B          462.790196         0.092478          0.080085        0.046058
# M          978.376415         0.102898          0.145188        0.160775
#
#            concave points_mean  symmetry_mean  ...  texture_worst  \
# diagnosis                                      ...
# B                     0.025717       0.174186  ...      23.515070
# M                     0.087990       0.192909  ...      29.318208
#
#            perimeter_worst   area_worst  smoothness_worst  compactness_worst  \
# diagnosis
# B                87.005938   558.899440          0.124959           0.182673
# M               141.370330  1422.286321          0.144845           0.374824
#
# ...

# %% [markdown]
# #### Observations from initial Exploratory analysis
#
# There dosn't appear to be any null data points from a total of 18,777, but some colums which are not useful to us right now can be removed. From the grouped data we get some interesting information. For example Area_mean mean value for Malignent is almost twice the size of Benign, where as smoothness_mean shows little difference between both.

# %% [markdown]
# <h1><center>Cleaning the data</center></h1>
# From the initial analysis we see the colums id and Unnamed will not be helpful to us right now so we can drop them. Also remap diagnosis from M/B to 1/0. [5] This is discussed a little further in feature selection below.
#
# Next check for corrolation between variables. This is easier to view in the form of a heat map, with high corrolation showing in Red. Of particular interest here are any high heat values along the diagnostics line. We see a few at 0.78--0.79 that may be useful to us.

# %%
df.drop('id',axis=1,inplace=True)
df.drop('Unnamed: 32',axis=1,inplace=True)
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df['diagnosis'] = df['diagnosis'].map({'M':1,'B':0})
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# <h1><center>Review of some available Litrature</center></h1>
#
# Before we go any further in selecting features or in choosing a machins learning model lets have a look at how it has been done before.
#
# Machine learning algorithms are a set of statistical, probabilistic and optimization methods used to learn large, unstructured and complex datasets detect useful patterns from them and make predictions within an acceptable range. Machine learning algorithms they can be divided broadly into three categories according to the way the machine is being taught. These categories are: supervised, unsupervised and semi-supervised. [20]
#
# Many studies have been carried out on the WDBC with a view to classifying samples correctly based on the data available. Some of the most common and successful techniques are:
# - Decision Tree
# - Random forest
# - Artificial Neural Networks (ANN)
# - Support Vector Machines (SVM)
# - Naive Bayes multinomial classifier (NBM)
# - K-nearest neighbors (KNN)
# - Logistic Regression
#
# ##### Decision Tree
# Decision Trees are a type of Supervised Machine Learning. You explain what the input is and what the corresponding output is in the training data. The data is repeatedly split according to a certain parameter. The tree will begin to grow based on two enteties called decision nodes and leaves. The resultant tree can be seen as a piecewise constant approximation.
#
# ##### Random forest classifier.
# A random forest is a meta estimator that fits a number of decision tree classifiers on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting.
#
# ##### Artificial Neural Network.
# A neural network consists of units (neurons), arranged in layers, which convert an input vector into some output. Each unit takes an input, applies a (often nonlinear) function to it and then passes the output on to the next layer.
#
# ##### Support Vector Machines
# Support vector machines (SVMs) are a set of supervised learning methods used for classification, regression and outliers detection. Developed at AT&T Bell Laboratories in 1997 SVMs are one of the most robust prediction methods, being based on statistical learning frameworks.
#
# ##### Bayesian Classifier
# Naive Bayes methods are a set of supervised learning algorithms based on applying Bayes’ theorem with the assumption of conditional independence between every pair of features. This method is called “naive” because the assumption that different attributes are independent of each other.
#
# ##### K-nearest neighbors
# The principle behind nearest neighbor methods is to find a predefined number of training samples closest in distance to the new point, and predict the label from these. The number of samples can be a user-defined constant (k-nearest neighbor learning), or vary based on the local density of points (radius-based neighbor learning)
#
# ##### Logistic regression
# Despite its name, it is implemented as a linear model for classification rather than regression. The logistic regression is also known in the sklearn literature as logit regression, maximum-entropy classification (MaxEnt) or the log-linear classifier.
# [8]
#
# #### Some notable studies include
#
# ##### Comparative study of relevance vector machine with various machine learning techniques used for detecting breast cancer
#
# B.M. Gayathri and C. P. Sumathi
#
# 2016 IEEE International Conference on Computational Intelligence and Computing Research (ICCIC), Chennai, [11]
#
# They find that Relevance vector machine provides Low computational cost compared to some other techniques on breast cancer classification. They created a user friendly environment for diagnosis. In the work the authors compare RVM with SVM for accuracy on the Wisconsin original dataset. RVM shows better accuracy. The dataset consist of 12 variables and they are reduced to four by using feature selection Algorithms. They shows there is not a great difference in results based on the number of variabled used, with accuracy up to 96%.
#
# In their Literature review they found RVM it was often tested on Cancer diagnosis with Lymphoma and Leukemia but not often with the Wisconsin Original Dataset. Their model runs with a user friendly interface where the user confirms the classification results. In this way they can determine the True Positive (TP), True Negative (TN), False Positive (FP) and False Negative (FN) results.
# ***
#
# ##### Using Machine Learning Algorithms for Breast Cancer Risk Prediction and Diagnosis
#
# H. Asri, H. Mousannif, H. A. Moatassime, and T. Noel
#
# Procedia Computer Science, vol. 83, pp. 1064–1069, 2016, doi: 10.1016/j.procs.2016.04.224 [12]
#
# They  compared the behaviours of SVM, NB, C4.5 and k -NN, by conducting experiments focused on assessing both the effectiveness, and the efficiency of the algorithms. More precisely, the research questions posed for the experiment are: Which algorithm exploits better effectiveness? Which algorithm is more efficient? Which algorithm provides a higher accuracy? The experiments were carried out on the Wisconsin Original Dataset. They found SVM is efficent in Breast Cancer diagnosis and achieves high accuracy with low error rate.
# ***
#
# ##### Supervised classification using gradient boosting machine: Wisconsin breast cancer dataset
#
# S. Aryal, B. Paudel, S. Aryal, and B. Paudel
#
# International Journal of Scientific Research and Engineering Trends, vol. 6, no. 3, pp. 1887–1892, 2020. [13]
#
# In their study they proposed breast cancer classification, using the Wisconsin Diagnostic Breast Cancer Dataset, with Gradient boosting Machines. Performance is  evaluated using accuracy, sensitivity, specificity, confusion matrix, positive predictive value, negative predictive value, receiver operating characteristic
# (ROC) curve, and area under the curve (AUC).
#
# Their Gradient boosting based model provided a great degree of accuracy with faster classification using less computing power when compared to deep learning models. Also, the accuracy yielded by the model is much higher than traditionally used models like random forest and logistic regression. With GB and and 10-fold cross-validation they achieved accuracy of 98.88% on the WDBC.
# ***
#
# ##### Classification and diagnostic prediction of breast cancers via different classifiers
#
# A. Saygili
#
# International Scientific and Vocational Studies Journal, vol. 2, pp. 48–56, 201 [14]
#
# In the study they used the Wisconsin Diagnostic Breast Cancer (WDBC) dataset to investigate the most successful breast cancer
# classification model. Support vector machines, k nearest neighborhood, Naive Bayes, J48 decision tree, random forest and multilayer perceptron methods were used in the classification. They compared classifications with and without applying any preprocessing steps. They found a significant increase in the success achieved when preprocessing of the data was applied. They achieved 98.77% with Random forest.
#
#
# Also in a research article published on Hindawi, Aamir Sanam and others [15] Performed classification experiments using SVM, Random Forest, Gradient Boosting, Artificial Neural Network, and Multilayer Perceptron Model on the WDBC dataset. They achieved 99.12% accuracy.
# ***
#
# In an interesting study published by Dutch company Elsevier in 2021, the performance of an number of these algorithms was compared on the WDBC dataset [10] The study gave an overall accuracy precentage for each of the chosen algorithms in training and testing, the results of which can be seen in the table below:
#
# Predicting Breast Cancer Leveraging Supervised Machine Learning Techniques
# Table 1 Comparison of machine learning algorithms on the WDBC dataset.
#
# Accuracy percentage for breast cancer diagnostic dataset.
# ****
# Algorithms Accuracy Training Set (%)   Accuracy Testing Set (%)
#
#         SVM                 98.4%            97.2%
#
#         Radom Forest        99.8%            96.5%
#
#         Logistic Regression 95.5%            95.8%
#
#         Decision Tree       98.8%            95.1%
#
#         K-NN                94.6%            93.7%
#  ****
# [10]

# %% [markdown]
# <h1><center>Feature Selection</center></h1>
# Feature selection is a key step in the project. I propose to select the best attributes to test by correlation-based feature selection (CFS), That is corrolation of the feature to the diagnosis (target). We can then evaluate based on their degree of positive or negative corrolation. The aim is to reduce the number of input variables by removing those that are precieved to have little corrolation to the diagnosis. In simple terms, if we put alot of rubbish into out algorithms we will get rubbish out. Apart from choosing the right model for our data, we need to choose the right data to put in our model. [16] In the case of the WDBC for example, the case ID number may confuse the algorithm, It may find some corrolation in the ID number that may skew the results so we can remove that column with some confidence we will not loose important features. It is important to note, while I am removing the case ID from the DF at this point, the information has not been discarded entirley. It may be the case that we revisit and include it at a later date. Case ID may for example relate to paitents geographical area which in turn may have some bearing on the likley diagnosis.
#
# Feature selection methods can generally be described as either supervised or unsupervised. Supervised selection methods include information of a given classe in the selection, while unsupervised methods can be used for selection without class labels.
#
# Checking for corrolation between variables and visualising using Seaborn .corr method. This is easier to view in the form of a heat map, with high corrolation showing in Red.
#
# Also a pairplot of all the mean values with Malignant points showing in Blue. We see high linear corrolation of some values. Perimeter_mean/Radius_mean, Area_mean/Radius_mean, Perimeter_mean/Area_mean.

# %%
import seaborn as sns
corr = df.corr()
fig, ax = plt.subplots(figsize=(18,18))   
ax = sns.heatmap(corr,xticklabels=corr.columns,
           yticklabels=corr.columns, 
           cmap="RdYlBu_r", annot=True,linewidth=0.5,)
            #select heat map colours and reverse, so red is for hot.

# %% [markdown]
# #### Observations from heatmap
# Of particular interest here are any high heat values along the diagnostics line. We see a few with high r value (Pearson’s correlation coefficient) 0.78 to 0.79  that may be useful to us.
#
# Also, from the heatmap, we see preimeter, area and radius means all have very high positive correlation to each other. I will investigate this further using the pairplot.

# %%
#scatterplot matrix of mean colums
import seaborn as sns
df_mean = df[df.columns[:11]]
#colums = ['diagnosis','radius_mean',
          #'texture_mean','perimeter_mean',
          #'area_mean','smoothness_mean',
          #'compactness_mean','concavity_mean',
          #'concave points_mean','symmetry_mean',
          #'fractal_dimension_mean']
sns.pairplot(data=df_mean, hue='diagnosis', palette='bright')
# Out:
# Text(0.5, 0.98, 'Main title')

# %% [markdown]
# #### Observations from pairplot
#
# We can see the variables mentioned earlier with high corralation to eachother show up in linear pattern. This shows us signs of Mulitcolinearity between these variables. In this case 1 of preimeter_mean, area_mean and radius_mean. Also there appears to be some collinearity with compactness_mean, concave_points_mean and concavity_mean.
#
# Multicollinearity is a special case of collinearity where a feature exhibits a linear relationship with two or more features. [19]
#
# To addressthis Multicollinearity we can drop some of the variables involved.

# %% [markdown]
# #### Correlation of data with diagnosis.
# Plotting all features against the diagnosis shows correlation if any with diagnosis.

# %%
plt.figure(figsize=(20, 8))
df.drop('diagnosis', axis=1).corrwith(df.diagnosis).plot(kind='bar', 
            grid=True, title="Correlation of Variables with Diagnosis");

# %% [markdown]
# Plotting mean features only against the diagnosis shows high correlation for all except fractral_dimensional_mean against diagnosis. [6]

# %%
df_mean = df[df.columns[:11]]
plt.figure(figsize=(20, 8))
df_mean.drop('diagnosis', axis=1).corrwith(df_mean.diagnosis).plot(kind='bar', 
            grid=True, title="Correlation of Mean Variables with Diagnosis");

# %% [markdown]
# #### Generating some useful dataframes form our dataset

# %%
#df_features = df.drop('diagnosis',axis=1,inplace=True)
df_mal = df[df['diagnosis'] == 1]
df_ben = df[df['diagnosis'] == 0]
df_target = df.iloc[:,0]
df_features = df.loc[:, df.columns != 'diagnosis']
df_mean_features = df.iloc[:,1:10]
#df_target.head()
#X = df_features.iloc[:, :-1])

# %% [markdown]
# #### Looking at distrubution of benign and malignant.
#
# Histplots of all the mean colums showing highlighting any seperations between M and B may be helpful. [17]

# %%
fig = plt.figure(figsize=(15,15))

# Create 'for loop' to enerate though tumor features and compare with histograms
for i,b in enumerate(list(df_mean_features)):
    
    # Enumerate starts at index 0, need to add 1 for subplotting
    i +=1
    
    # Create axes object for position i
    ax = fig.add_subplot(3,4,i)
    
    # Plot via histogram tumor charateristics using stacked and alpha parameters for..
    # comparisons.
    sns.histplot(df_ben[b], kde=True, label='Benign',color='green')
    sns.histplot(df_mal[b], kde=True, label='Malignant',color='red')
   
    ax.set_title(b)

sns.set_style("whitegrid")
plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# #### Observations from distrubution of benign and malignant.
#
# Again we can see some seperation between M and B in Perimeter_mean, Area_mean, Radius_mean and also maybe in concave colums.

# %% [markdown]
# <h1><center>Divide the data into train and test sets</center></h1>
#
# We need to devide the data based on features (X) and target (y)
#
# X will be all the features used by the machine algorithm to make predictions. The characteristics correspond to the names of the columns.
# y then refers to a target variable (the correct result or answer). In this case, what the machine is to predice, so malignant (1) or benign (0).
#
# Split and Train data.

# %%
# store data in new variables X and Y
X = df_features
y = df_target

# Split the data using Scikit-Learn‘s train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# <h1><center>Selecting a Machine Learning Model</center></h1>
#
# From the models mentioned in the litrature review, lets take a few machine learning models.
#
#
# K-nearest neighbors, Random Forest, Gaussian Bias and a Support Vector Machine learning in the form of SVC. [18]

# %%
models = {"Logistic regression": LogisticRegression(max_iter=10000),
          "KNN": KNeighborsClassifier(),
          "Linear SVC": LinearSVC(max_iter=10000),
          "Random Forest": RandomForestClassifier(),
            "Gaussian Bias": GaussianNB()}

# %%
 # Create a funtion to train (fit) and score models
def train_score(models, X_train, X_test, y_train, y_test):
  # Set random seed
  np.random.seed(0)
  # Make an empty dictionary for model scores
  scores = {}  
  # Loop through models
  for name, model in models.items():
      #Fit the model to the data
      model.fit(X_train, y_train)
#Evaluate the model and append its score to the scores dictionary
      scores[name] = model.score(X_test, y_test)
  return scores

# %%
# let‘s try the function
scores = train_score(models = models,
                   X_train = X_train,
                   X_test = X_test,
                   y_train = y_train,
                   y_test = y_test)

print(scores)
# Out:
# C:\Users\JS\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# {'Logistic regression': 0.9473684210526315, 'KNN': 0.9385964912280702, 'Linear SVC': 0.9298245614035088, 'Random Forest': 0.9649122807017544, 'Gaussian Bias': 0.9298245614035088}

# %%
#Model comparison
model_compare = pd.DataFrame(scores, index=["accuracy"])
model_compare.T.plot.bar();

# %% [markdown]
# ### Acknowledgements
#
# [A] Source of the dataset: University of Wisconsin Hospitals, Madison from Dr. William H. Wolberg. If you publish results when using this database, then please include this information in your acknowledgements.
#
# 1. O. L. Mangasarian and W. H. Wolberg: "Cancer diagnosis via linear programming", SIAM News, Volume 23, Number 5, September 1990, pp 1 & 18.
# 2. William H. Wolberg and O.L. Mangasarian: "Multisurface method of pattern separation for medical diagnosis applied to breast cytology", Proceedings of the National Academy of Sciences, U.S.A., Volume 87, December 1990, pp 9193-9196.
# 3. O. L. Mangasarian, R. Setiono, and W.H. Wolberg: "Pattern recognition via linear programming: Theory and application to medical diagnosis", in: "Large-scale numerical optimization", Thomas F. Coleman and Yuying Li, editors, SIAM Publications, Philadelphia 1990, pp 22-30.
# 4. K. P. Bennett & O. L. Mangasarian: "Robust linear programming discrimination of two linearly inseparable sets", Optimization Methods and Software 1, 1992, 23-34 (Gordon & Breach Science Publishers).
#
# [B] https://scikit-learn.org/stable/index.html Data analysis machine learning algorithms used in the project are in the Python programming language and from the Scikit-learn library (sklearn). Sklearn is a free software machine learning library of algoritnms for the Python programming language. It contains many classification regression and clustering algorithms including all those listed above.

# %% [markdown]
# References
# [1]  (kaggle.com, Breast Cancer Wisconsin (Diagnostic) Data Set, Nov 2022)
#     https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data/download?datasetVersionNumber=2
#
# [2] (uci breast cancer wisconsin, Dec 2022)
#     https://archive.ics.uci.edu/ml/datasets/breast+cancer+wisconsin+(diagnostic)
#
# [3] (cancer.ie screening for breastcancer Nov 2022)
#     https://www.cancer.ie/cancer-information-and-support/cancer-types/breast-cancer/screening-for-breast-cancer
#
# [4] (Machine Learning for Cancer Diagnosis and Prognosis, Dec 2022)
#     https://pages.cs.wisc.edu/~olvi/uwmp/cancer.html
#
# [5] (Breast Cancer Wisconsin Data Analysis: Machine Learning Project | Exploratory Data Analysis Dec 2022)
#     https://www.youtube.com/watch?v=2ncx2q5GHbQ
#
# [6] https://medium.com/analytics-vidhya/breast-cancer-diagnostic-dataset-eda-fa0de80f15bd
#
# [7] https://www.wcrf.org/cancer-trends/worldwide-cancer-data/
#
# [8] https://scikit-learn.org/stable/supervised_learning.html
#
# [9] (Predicting Breast Cancer Leveraging Supervised Machine Learning Techniques, Sujatha Krishnamoorthy, 16 Aug 2022)
#      https://www.hindawi.com/journals/cmmm/2022/5869529/ Innovation in Deep Learning Approaches for Medical Data/Big Data Analysis
#
# [10] Machine Learning Algorithms For Breast Cancer Prediction And Diagnosis, Habib Benlahmard, Rachida Ait Abdelouhah, Kawtar Aarikac, EL Habib Benlahmard, Rachida Ait Abdelouhahide, Olivier Debauche, 8 Sept 2021)
# https://www.sciencedirect.com/science/article/pii/S1877050921014629
#
# [11] B.M. Gayathri and C. P. Sumathi, "Comparative study of relevance vector machine with various machine learning techniques used for
# detecting breast cancer," 2016 IEEE International Conference on Computational Intelligence and Computing Research (ICCIC), Chennai,
# 2016, pp. 1-5.
#
# [12] H. Asri, H. Mousannif, H. A. Moatassime, and T. Noel, ‘Using Machine Learning Algorithms for Breast Cancer Risk Prediction and
#  Diagnosis’, Procedia Computer Science, vol. 83, pp. 1064–1069, 2016, doi: 10.1016/j.procs.2016.04.224
#
# [13] S. Aryal, B. Paudel, S. Aryal, and B. Paudel, “Supervised classification using gradient boosting machine: Wisconsin breast cancer dataset,” International Journal of Scientific Research and Engineering Trends, vol. 6, no. 3, pp. 1887–1892, 2020.
#
# [14] A. Saygili, “Classification and diagnostic prediction of breast cancers via different classifiers,” International Scientific and Vocational Studies Journal, vol. 2, pp. 48–56, 201
#
# [15] (Predicting Breast Cancer Leveraging Supervised Machine Learning Techniques, Aamir Sanam, Rahim Aqsa, Aamir Zain, Abbasi Saadullah Farooq, Khan Muhammad Shahbaz, Alhaisoni Majed, Khan, Muhammad Attique Khan, Khan Khyber, Ahmad Jawad, Computational & Mathematical Methods in Medicine. 8/16/2022) p1-13. 13p
#
# [16] (Everything You Need to Know About Feature Selection In Machine Learning, Kartik Menon, 15 Nov 2022) https://www.simplilearn.com/tutorials/machine-learning-tutorial/feature-selection-in-machine-learning#why_feature_selection
#
# [17] https://github.com/pkmklong/Breast-Cancer-Wisconsin-Diagnostic-DataSet/blob/master/Breast%20Cancer%20Wisconsin%20(Diagnostic)%20DataSet_Orignal_Data_In_Progress.ipynb
#
# [18]  (Breast cancer classification, N. ŽDANOVIČ, June 2022) https://www.kaggle.com/code/schmoyote/breast-cancer-classification-beginner-friendly/notebook
#
# [19] (Statistics in Python — Collinearity and Multicollinearity, Wei-Meng Lee, Oct 2021) https://towardsdatascience.com/statistics-in-python-collinearity-and-multicollinearity-4cc4dcd82b3f
#
# [20] (Comparing different supervised machine learning algorithms for disease prediction, Shahadat Uddin, Arif Khan, Md Ekramul Hossain & Mohammad Ali Moni, Dec 2019) Retreived from: https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-019-1004-8
